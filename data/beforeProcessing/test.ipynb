# %%
import pandas as pd
from pathlib import Path



column_names=["unit","cycle"]+[f"op{i}" for i in range(1,4)]+[f"s{i}" for i in range(1,22)]
df=pd.read_csv("test_FD004.txt",sep=r"\s+",header=None,names=column_names)
df.head(50)

df.to_csv("test_FD004.csv",index=False)
